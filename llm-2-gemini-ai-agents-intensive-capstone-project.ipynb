# %% [markdown]
# <a href="https://www.kaggle.com/code/gallo33henrique/llm-2-gemini-ai-agents-intensive-capstone-project?scriptVersionId=281102854" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Clinical Trials Navigator Agent for COVID-19 Research**
#
# - A Gemini-powered multi-agent system that helps patients, caregivers, and clinicians discover, interpret, and understand COVID-19 clinical trials using public data from ClinicalTrials.gov.

# %% [markdown]
# # BUSINESS CONTEXT
#
# The COVID-19 pandemic triggered the largest coordinated scientific research effort in modern history. Thousands of clinical studies were launched worldwide in an attempt to understand the virus, evaluate potential treatments, test vaccines, monitor long-term effects, and protect vulnerable populations.
#
# Even though all these clinical trials are **publicly available** on ClinicalTrials.gov, they remain **extremely difficult for patients and non-experts to navigate**. Trial descriptions are written in technical biomedical language, eligibility criteria are long and complex, and searching through hundreds of studies requires expertise, time, and medical literacy.
#
# As a result:
#
# * Patients often fail to find trials that could be medically relevant
# * Caregivers cannot correctly interpret eligibility requirements
# * Clinicians are overwhelmed with the volume of studies
# * Researchers struggle to identify suitable candidates for enrollment
#
# The accessibility gap has nothing to do with lack of data — the data is public — but rather the lack of **intelligent tools that make this information understandable and actionable** for ordinary people.
#
# **BUSINESS PROBLEM**
#
# **How can we enable any patient, caregiver, or healthcare provider to quickly find, understand, and evaluate relevant COVID-19 clinical trials, without requiring medical expertise?**
#
# Today, this process is:
#
# * manual
# * time-consuming
# * cognitively overwhelming
# * error-prone
# * inaccessible to non-experts
#
# Users struggle to answer fundamental questions:
#
# * “Which clinical trials apply to my situation?”
# * “Am I likely to meet the eligibility criteria?”
# * “What is the treatment or intervention?”
# * “What phase is this trial in?”
# * “What does participation involve?”
# * “How do I discuss this with my doctor?”
#
# This is especially problematic during global emergencies — such as COVID-19 — where timely access to accurate information directly impacts public health decisions.
#
# **3. DATASET USED (COVID-19 Clinical Trials — Kaggle)**
#
# The project uses the **COVID-19 Clinical Trials Dataset**, a structured extraction of ClinicalTrials.gov XML files, containing:
#
# * study title
# * NCT identifier
# * study type (interventional, observational)
# * phase (Phase 1, Phase 2, Phase 3…)
# * conditions (e.g., “COVID-19”, “SARS-CoV-2 infection”)
# * interventions
# * eligibility criteria
# * study design
# * enrollment numbers
# * start/completion dates
# * sponsors/collaborators
# * study locations
#
# Dataset link:
# [https://www.kaggle.com/datasets/paultimothymooney/covid19-clinical-trials](https://www.kaggle.com/datasets/paultimothymooney/covid19-clinical-trials)
#
# This dataset provides **real medical complexity** while still being manageable for a Kaggle Notebook (much smaller than the full ClinicalTrials.gov dump).
#
# It contains:
#
# * Thousands of authentic COVID-19 research studies
# * Long, detailed eligibility criteria
# * Rich contextual metadata
# * Diverse interventions (vaccines, antivirals, immune therapies, supportive care)
# * Global geographic coverage
#
# This makes it ideal for:
#
# * multi-agent reasoning
# * medical text summarization
# * eligibility extraction
# * information retrieval
# * patient-oriented explanation
#
# **4. SOLUTION — Clinical Trials Navigator Agent**
#
# The **Clinical Trials Navigator Agent** is a multi-agent, Gemini-powered system that transforms raw COVID-19 clinical trial data into personalized, human-readable insights.
#
# A user can simply type:
#
# > “My father is 62, diabetic, post-COVID with respiratory complications, living in São Paulo.”
#
# And the agent pipeline will:
#
# 1. **understand and structure the medical profile**
# 2. **search the COVID-19 clinical trials dataset**
# 3. **filter and rank the most relevant trials**
# 4. **interpret eligibility criteria**
# 5. **generate a customized, patient-friendly report**
# 6. **add disclaimers and safety notes**
#
# The goal is not to provide medical advice but to make **public health research data accessible and understandable**.
#
# **5. MULTI-AGENT ARCHITECTURE**
#
# The system consists of five specialized agents:
#
# **Agent 1 — Intake & Medical Profile Normalization Agent**
#
# **Task:**
# Convert a plain-language user description into a structured representation:
#
# * age range
# * sex (if mentioned)
# * comorbidities (diabetes, hypertension, asthma…)
# * disease stage/severity
# * COVID-19 context (acute infection, long COVID, post-hospitalization, vaccination status)
# * geographic location
#
# **Purpose:**
# Build a clean, machine-readable patient profile.
#
# **Agent 2 — Retrieval & Ranking Agent**
#
# **Task:**
# Search COVID-19 clinical trials and select the best matches based on:
#
# * condition keywords
# * age requirements
# * study phase
# * geographic region
# * intervention type
# * enrollment status (recruiting, completed, active)
#
# **Methods:**
# Uses custom search functions + LLM reasoning + pandas filtering.
#
# **Agent 3 — Eligibility Interpretation Agent**
#
# **Task:**
# Analyze complex eligibility criteria from the dataset:
#
# * inclusion/exclusion rules
# * lab value requirements
# * comorbidity constraints
# * treatment history
# * COVID-19 severity definitions
#
# Produces a **fit likelihood** label:
#
# * "Likely Eligible"
# * "Possibly Eligible"
# * "Unlikely Eligible"
#
# Along with a structured justification.
#
# **Agent 4 — Patient-Friendly Explainer Agent**
#
# **Task:**
# Convert biomedical text into **clear, easy-to-read language**:
#
# * explain trial purpose
# * describe interventions
# * summarize participation expectations
# * highlight key eligibility points
# * remove technical jargon
#
# This is the main “user-facing” communication agent.
#
# **Agent 5 — Report Generation Agent**
#
# **Task:**
# Produce a formatted summary the user can share with a physician:
#
# * patient profile
# * list of relevant trials
# * plain-language explanations
# * eligibility assessment
# * study phase, design, location
# * disclaimers: “Not medical advice — consult a doctor.”
#
# Output format:
#
# * Markdown
# * PDF
# * Structured table
#
# (Optional tools can export to PDF.)
#
# **6. VALUE PROPOSITION**
#
# **For Patients**
#
# * makes complex medical research understandable
# * gives autonomy and clarity
# * enables informed discussions with physicians
#
# **For Caregivers**
#
# * reduces confusion and information overload
# * bridges the gap between technical research and real-world concerns
#
# **For Healthcare Providers**
#
# * saves time by automating trial search
# * organizes results clearly
# * improves referral efficiency
#
# **For Public Health**
#
# * supports research equity
# * accelerates patient-trial matching
# * enhances accessibility of scientific information
#
# **7. WHY THIS PROJECT MATTERS**
#
# 1. **Increases health literacy**
#    COVID-19 is a global issue; accessible information is crucial.
#
# 2. **Brings clinical research to the general public**
#    Not everyone understands medical jargon or trial design.
#
# 3. **Promotes responsible AI in healthcare**
#    The system provides understanding, not diagnosis.
#
# 4. **High real-world applicability**
#    Governments, hospitals, and NGOs could easily adapt it.
#
# 5. **Strong alignment with Agents for Good**
#    Clear societal benefit → accessibility → public health improvement.
#
# **8. ALIGNMENT WITH COMPETITION REQUIREMENTS**
#
# ### ✔ Multi-Agent System
#
# (5 agents: Intake, Retrieval, Eligibility, Explainer, Report)
#
# ### ✔ Tools
#
# * pandas filtering tool
# * eligibility parser tool
# * code execution
# * optional HTTP search
#
# ### ✔ Sessions & Memory
#
# * patient profile memory
# * trial shortlists kept across steps
#
# ### ✔ Long-running operations
#
# * large dataset filtering
# * resume/pause analysis flow
#
# ### ✔ Context Engineering
#
# * eligibility criteria compaction
# * structured prompts
#
# ### ✔ Observability
#
# * logging: matched trials, eligibility decisions, errors
# * metrics: number of trials processed, confidence level
#
# ### ✔ Agent Evaluation
#
# * check that each trial explanation includes required sections
#
# ### ✔ Use of Gemini
#
# * Gemini 2.5 Pro (reasoning)
# * Gemini Flash (fast filtering)
#
# **9. FINAL PITCH (POWERFUL, 1-PARAGRAPH VERSION)**
#
# The Clinical Trials Navigator Agent democratizes access to COVID-19 research by transforming complex clinical trial data into understandable insights. Using a multi-agent Gemini architecture, the system converts a user-provided medical description into a structured profile, retrieves relevant COVID-19 clinical trials from public datasets, interprets eligibility criteria, and generates clear, patient-friendly summaries with safety disclaimers. This project empowers patients, supports clinicians, and increases equity in access to clinical research — aligning directly with the mission of the Agents for Good track: using AI to improve health outcomes and reduce barriers in global healthcare.

# %% [markdown]
# # 1. INSTALL & SETUP (Kaggle)

# %%
# !pip install -U google-generativeai
# !pip install google-generativeai --quiet
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.177.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.12.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.0.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.10.5)

# %%
import pandas as pd
import logging
import time
from google import generativeai as genai
from kaggle_secrets import UserSecretsClient
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import json

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

# %% [markdown]
# # 2. API LLM Gemini

# %%
# Load Google API Key securely from Colab Secrets

# The UserSecretsClient allows you to securely store and access
# private keys in Google Colab without exposing them in the notebook.
user_secrets = UserSecretsClient()

# Retrieve the API key stored under the name "Gemini_LLM".
# This keeps the key hidden and prevents accidental leaks.
GOOGLE_API_KEY = user_secrets.get_secret("Gemini_LLM")

# Configure the Gemini client with the retrieved API key.
# This enables all subsequent LLM calls to authenticate using this key.
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# # 3. Model LLM

# %%
# Lists all LLM models available in your Google Generative AI account
models = genai.list_models()

# Prints each model name
for model in models:
    print(model.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/gemini-2.0-flash-live-001
# models/gemini-live-2.5-flash-preview
# models/gemini-2.5-flash-live-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025

# %%
# Model LLM
llm = genai.GenerativeModel("models/gemini-2.5-flash")

# %%
# Test prompt 1
resp = llm.generate_content("Explain RNA-seq in 2 lines.")
print(resp.text)
# Out:
# RNA-seq uses high-throughput sequencing to identify and quantify all RNA molecules (transcripts) in a sample. It provides a comprehensive snapshot of gene expression, revealing active genes and their relative abundance.

# %%
# Test prompt 2
resp2 = llm.generate_content("Explain RNA-seq in 2 lines with temporal dilation.")
print(resp2.text)
# Out:
# We seize a fleeting instant of a cell's life and expand it, sequence by sequence, across an eon.
# This single, dilated moment then unfolds, revealing the echoes of its genetic past and whispering its potential biological futures.

# %% [markdown]
# # **4. LOAD DATASET (COVID-19 Clinical Trials)**

# %%
# Database
df = pd.read_csv("/kaggle/input/covid19-clinical-trials-dataset/COVID clinical trials.csv")

# View database
df.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0     1  NCT04785898  Diagnostic Performance of the ID Now™ COVID-19...
# 1     2  NCT04595136  Study to Evaluate the Efficacy of COVID19-0001...
# 2     3  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3     4  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 4     5  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
#
#         Acronym                  Status         Study Results  \
# 0   COVID-IDNow  Active, not recruiting  No Results Available
# 1      COVID-19      Not yet recruiting  No Results Available
# 2   TAC-COVID19              Recruiting  No Results Available
# 3      COVID-19  Active, not recruiting  No Results Available
# 4  TMF-COVID-19              Recruiting  No Results Available
#
#                                           Conditions  \
# 0                                            Covid19
# 1                               SARS-CoV-2 Infection
# 2                                            covid19
# 3                                              COVID
# 4  Maternal Fetal Infection Transmission|COVID-19...
#
#                                        Interventions  \
# 0   Diagnostic Test: ID Now™ COVID-19 Screening Test
# 1    Drug: Drug COVID19-0001-USR|Drug: normal saline
# 2  Other: Lung CT scan analysis in COVID-19 patients
# 3          Diagnostic Test: COVID 19 Diagnostic Test
# 4  Diagnostic Test: Diagnosis of SARS-Cov2 by RT-...
#
#                                     Outcome Measures  \
# 0  Evaluate the diagnostic performance of the ID ...
# 1  Change on viral load results from baseline aft...
# 2  A qualitative analysis of parenchymal lung dam...
# 3  Proportion of asymptomatic subjects|Proportion...
# 4  COVID-19 by positive PCR in cord blood and / o...
#
#                                Sponsor/Collaborators  ...         Other IDs  \
# 0              Groupe Hospitalier Paris Saint Joseph  ...       COVID-IDNow
# 1                         United Medical Specialties  ...  COVID19-0001-USR
# 2                       University of Milano Bicocca  ...       TAC-COVID19
# 3                    Hong Kong Sanatorium & Hospital  ...        RC-2020-08
# 4  Centre Hospitalier Régional d'Orléans|Centre d...  ...      CHRO-2020-10
#
#          Start Date Primary Completion Date   Completion Date  \
# 0  November 9, 2020       December 22, 2020    April 30, 2021
# 1  November 2, 2020       December 15, 2020  January 29, 2021
# 2       May 7, 2020           June 15, 2021     June 15, 2021
# 3      May 25, 2020           July 31, 2020   August 31, 2020
# 4       May 5, 2020                May 2021          May 2021
#
#        First Posted Results First Posted Last Update Posted  \
# 0     March 8, 2021                  NaN      March 8, 2021
# 1  October 20, 2020                  NaN   October 20, 2020
# 2      May 20, 2020                  NaN   November 9, 2020
# 3      June 4, 2020                  NaN       June 4, 2020
# 4      May 20, 2020                  NaN       June 4, 2020
#
#                                            Locations Study Documents  \
# 0  Groupe Hospitalier Paris Saint-Joseph, Paris, ...             NaN
# 1       Cimedical, Barranquilla, Atlantico, Colombia             NaN
# 2  Ospedale Papa Giovanni XXIII, Bergamo, Italy|P...             NaN
# 3  Hong Kong Sanatorium & Hospital, Hong Kong, Ho...             NaN
# 4                       CHR Orléans, Orléans, France             NaN
#
#                                            URL
# 0  https://ClinicalTrials.gov/show/NCT04785898
# 1  https://ClinicalTrials.gov/show/NCT04595136
# 2  https://ClinicalTrials.gov/show/NCT04395482
# 3  https://ClinicalTrials.gov/show/NCT04416061
# 4  https://ClinicalTrials.gov/show/NCT04395924
#
# [5 rows x 27 columns]

# %%
df.columns.tolist()
# Out:
# ['Rank',
#  'NCT Number',
#  'Title',
#  'Acronym',
#  'Status',
#  'Study Results',
#  'Conditions',
#  'Interventions',
#  'Outcome Measures',
#  'Sponsor/Collaborators',
#  'Gender',
#  'Age',
#  'Phases',
#  'Enrollment',
#  'Funded Bys',
#  'Study Type',
#  'Study Designs',
#  'Other IDs',
#  'Start Date',
#  'Primary Completion Date',
#  'Completion Date',
#  'First Posted',
#  'Results First Posted',
#  'Last Update Posted',
#  'Locations',
#  'Study Documents',
#  'URL']

# %% [markdown]
# # 5. Classe base Agent

# %%
class Agent:
    def __init__(self, name, description, model):
        # Store agent metadata
        self.name = name
        self.description = description
        self.model = model

    def run(self, state):
        # Must be implemented in subclasses
        raise NotImplementedError("Implement in subclasses")


class IntakeAgent(Agent):
    def run(self, state):
        # Read user description from the pipeline state
        user_text = state["user_description"]

        # Prompt instructing the model to convert free-text into JSON
        prompt = f"""
You are a medical intake assistant.

Convert the following patient description into a JSON object with the fields:
- age (number)
- sex (string)
- condition (string)
- symptoms (list of strings)
- comorbidities (list of strings)
- location (string)

Return ONLY valid JSON with no markdown.
User description: {user_text}
"""

        # Call the LLM
        resp = llm.generate_content(prompt)

        # Clean model output in case markdown fences appear
        cleaned = resp.text.strip()
        cleaned = cleaned.replace("```json", "").replace("```", "")

        # Attempt to parse JSON safely
        try:
            profile = json.loads(cleaned)
        except:
            # Fallback to raw text if parsing fails
            profile = {"raw_profile": cleaned}

        # Store parsed patient profile back into state
        state["patient_profile"] = profile

        # Return updated state
        return state

# %%
# Base agent class that all agents inherit from
class Agent:
    # Initialize the agent with name, description, and model
    def __init__(self, name: str, description: str, model):
        self.name = name
        self.description = description
        self.model = model

    # Main execution method, must be implemented by subclasses
    def run(self, state: dict) -> dict:
        raise NotImplementedError("Subclasses must implement run().")

# %% [markdown]
# # 5.1 - Logging + Memory Store

# %%
# Configure basic logging behavior for the application
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

# Simple in-memory key-value store used to pass information between agents
class MemoryStore:
    def __init__(self):
        # Internal dictionary to hold stored values
        self.store = {}

    # Save a value under a specific key
    def save(self, key, value):
        self.store[key] = value

    # Retrieve a value associated with a key
    def get(self, key):
        return self.store.get(key)

# Create a global memory store instance
memory = MemoryStore()

# %% [markdown]
# # 5.2 - Classe Agent Base

# %%
# Base class for all agents in the pipeline
class Agent:
    def __init__(self, name, description, model):
        # Store agent metadata
        self.name = name
        self.description = description
        self.model = model

    # Method that must be implemented by subclasses
    def run(self, state):
        raise NotImplementedError

# %% [markdown]
# # 5.3 - Database Agent

# %%
# Load clinical trials dataset
df = pd.read_csv("/kaggle/input/covid19-clinical-trials-dataset/COVID clinical trials.csv")

# Remove rows where essential fields are missing
df = df.dropna(subset=["Title", "Conditions"])

# Create a small sample for quick testing
df_small = df.sample(300, random_state=42).reset_index(drop=True)

# Display preview
df_small.head()
# Out:
#    Rank   NCT Number                                              Title  \
# 0  1887  NCT04405310  Convalescent Plasma of Covid-19 to Treat SARS-...
# 1  2068  NCT04376944  Barrier Measures to Limit Covid-19.Nosocomial ...
# 2  3335  NCT04476680  Influence of Military Preventive Policy for re...
# 3  4066  NCT04703270  Understanding COVID-19 Infection in Pregnant W...
# 4   157  NCT04452682  The Impact of COVID-19 Pandemic on Critical Li...
#
#        Acronym      Status         Study Results  \
# 0     CPC-SARS   Completed  No Results Available
# 1     EMBELLIE  Recruiting  No Results Available
# 2  IMPACTCOVID  Recruiting  No Results Available
# 3    periCOVID  Recruiting  No Results Available
# 4          NaN   Completed  No Results Available
#
#                                           Conditions  \
# 0                                     SARS Pneumonia
# 1                                Caregivers|COVID-19
# 2  SARS-CoV Infection|Vitamin D Deficiency|Covid1...
# 3  Corona Virus Infection|Pregnancy Related|Neona...
# 4                       COVID|Critical Limb Ischemia
#
#                                        Interventions  \
# 0  Biological: Convalescent Plasma of patients wi...
# 1                                      Other: Survey
# 2                      Dietary Supplement: Vitamin D
# 3                                                NaN
# 4                             Other: COVID 19 impact
#
#                                     Outcome Measures  \
# 0  Death|Lenth of stay ICU|Days of Mechanical Ven...
# 1  Proportion of caregivers and agents with a pos...
# 2  Seroconversion|Interim analysis - seropositivi...
# 3  Antibody concentrations in maternal and cord b...
# 4  The ICU admission with associated Pneumonia|Im...
#
#                                Sponsor/Collaborators  ...  \
# 0  Grupo Mexicano para el Estudio de la Medicina ...  ...
# 1                   University Hospital, Montpellier  ...
# 2  Royal Centre for Defence Medicine|Leeds Becket...  ...
# 3                  St George's, University of London  ...
# 4                                Mansoura University  ...
#
#                   Other IDs         Start Date Primary Completion Date  \
# 0           DI/20/201/04/19       May 20, 2020       November 20, 2020
# 1            RECHMPL20_0261      April 1, 2020        December 1, 2020
# 2              1070MODREC20  September 1, 2020          April 28, 2021
# 3                 2020.0276    January 4, 2021         January 3, 2023
# 4  R.20.06.898 - 2020/06/16       May 25, 2020           June 21, 2020
#
#      Completion Date      First Posted Results First Posted  \
# 0  December 10, 2020      May 28, 2020                  NaN
# 1  December 30, 2020       May 6, 2020                  NaN
# 2     April 28, 2021     July 20, 2020                  NaN
# 3    January 3, 2023  January 11, 2021                  NaN
# 4      June 21, 2020     June 30, 2020                  NaN
#
#   Last Update Posted                                          Locations  \
# 0  December 21, 2020  Hospital Nava de Alta Especialidad, Mexico Cit...
# 1        May 6, 2020                Uh Montpellier, Montpellier, France
# 2     March 23, 2021  Headingley and City campuses, Leeds Beckett Un...
# 3   January 11, 2021  St George's, University of London, London, Uni...
# 4      June 30, 2020               Mansoura university, Mansoura, Egypt
#
#   Study Documents                                          URL
# 0             NaN  https://ClinicalTrials.gov/show/NCT04405310
# 1             NaN  https://ClinicalTrials.gov/show/NCT04376944
# 2             NaN  https://ClinicalTrials.gov/show/NCT04476680
# 3             NaN  https://ClinicalTrials.gov/show/NCT04703270
# 4             NaN  https://ClinicalTrials.gov/show/NCT04452682
#
# [5 rows x 27 columns]

# %%
def count_trials_by_condition(condition: str):
    """
    Count how many clinical trials match a given condition.

    Returns:
        A dictionary containing:
        - condition: searched condition
        - total_trials: number of trials found
        - examples: first 3 matching trials with key fields
    """
    # Filter trials where the condition appears in the "Conditions" column
    subset = df_small[df_small["Conditions"].str.contains(condition, case=False, na=False)]

    # Build the result payload
    return {
        "condition": condition,
        "total_trials": len(subset),
        "examples": subset[["NCT Number", "Title", "Phases", "Status"]]
                       .head(3)
                       .to_dict(orient="records")
    }

# Tool registry used by the agent
TOOLS = {
    "count_trials_by_condition": count_trials_by_condition
}

# %% [markdown]
# # 6.IntakeAgent: interpreta descrição do usuário

# %%
# IntakeAgent: extract structured patient data
class IntakeAgent(Agent):
    def run(self, state):
        logging.info("Running IntakeAgent")

        user_text = state["user_text"]

        prompt = f"""
Extract the following fields and return valid JSON only:
- age
- sex
- condition
- symptoms
- comorbidities
- location

Text:
{user_text}
"""

        response = self.model.generate_content(prompt)
        profile_json = response.text

        state["patient_profile"] = profile_json
        memory.save("patient_profile", profile_json)

        return state


# RetrievalAgent: retrieve clinical trials for a condition
class RetrievalAgent(Agent):
    def run(self, state):
        logging.info("Running RetrievalAgent")

        condition = "COVID"

        import numpy as np

        subset = df_small[df_small["Conditions"].str.contains(condition, case=False, na=False)]
        subset = subset.replace({np.nan: None})

        examples = (
            subset[["NCT Number", "Title", "Phases", "Status"]]
            .head(3)
            .to_dict(orient="records")
        )

        tool_output = {
            "condition": condition,
            "total_trials": len(subset),
            "examples": examples
        }

        state["tool_result"] = tool_output
        memory.save("tool_result", tool_output)

        if "plot_trial_status" in TOOLS:
            try:
                plot_path = TOOLS["plot_trial_status"]()
                state["status_plot_path"] = plot_path
                memory.save("status_plot_path", plot_path)
            except Exception as e:
                logging.error(f"Plot tool failed: {e}")
                state["status_plot_path"] = None

        return state

# %% [markdown]
# # 7. ExplainerAgent: gera explicação em linguagem simples - prompt

# %%
# ExplainerAgent: generates a simple-language explanation
class ExplainerAgent(Agent):
    def run(self, state):
        logging.info("Running ExplainerAgent")

        # Retrieve previous tool output
        tool_info = memory.get("tool_result")

        # Build instruction for the LLM
        prompt = f"""
Explain the following clinical trial information in simple, patient-friendly language:

{tool_info}
"""

        response = self.model.generate_content(prompt)
        explanation = response.text

        # Save explanation back to state and memory
        state["explanation"] = explanation
        memory.save("explanation", explanation)

        return state

# %% [markdown]
# # 8. ReportAgent: monta relatório final

# %%
class ReportAgent(Agent):
    def run(self, state):
        logging.info("Running ReportAgent")

        # Load stored components
        patient = memory.get("patient_profile")
        tool_res = memory.get("tool_result")
        explanation = memory.get("explanation")
        plot_path = memory.get("status_plot_path")

        import json

        # Parse patient JSON
        try:
            cleaned = (
                patient.replace("```json", "")
                       .replace("```", "")
                       .strip()
            )
            patient_json = json.dumps(json.loads(cleaned), indent=2)
        except:
            patient_json = "{}"

        # Parse tool result JSON
        try:
            tool_json = json.dumps(tool_res, indent=2)
        except:
            tool_json = "{}"

        # Build the final report
        final_report = (
            "# 🧭 Clinical Trials Navigator — Final Report\n\n"
            "## Patient Profile\n"
            "```json\n"
            f"{patient_json}\n"
            "```\n\n"
            "## Trials Found\n"
            "```json\n"
            f"{tool_json}\n"
            "```\n\n"
            "## Explanation\n"
            f"{explanation}\n\n"
        )

        # Attach plot information if available
        if plot_path:
            final_report += (
                "## Trial Status Chart\n"
                f"Plot saved at: `{plot_path}`\n\n"
            )

        # Add disclaimer
        final_report += (
            "## Medical Disclaimer\n"
            "This report is generated by an AI agent and is not medical advice.\n"
            "Always consult a licensed healthcare professional.\n"
        )

        # Save report
        state["final_report"] = final_report
        memory.save("final_report", final_report)

        return state

# %% [markdown]
# # 9. Pipeline completo

# %%
# Runs all agents and returns the final state
def run_pipeline(user_text):
    # Initialize shared state with the user text
    state = {"user_text": user_text}

    # List of agents executed in sequence
    agents = [
        IntakeAgent("intake", "Extract patient info", llm),
        RetrievalAgent("retrieval", "Search dataset with tools", llm),
        ExplainerAgent("explainer", "Explain results", llm),
        ReportAgent("report", "Generate final report", llm)
    ]

    # Execute each agent step-by-step
    for agent in agents:
        t1 = time.time()
        state = agent.run(state)
        t2 = time.time()

        # Log execution time
        logging.info(f"{agent.name} took {t2 - t1:.2f}s")

    # Return the enriched state after all agents run
    return state

# %% [markdown]
# # 10. Test run Agent

# %%
# Example patient description
user_text = (
    "My father is 62 years old, male, diabetic, with breathing problems after COVID-19, "
    "living in Brazil. We want to know if there are any COVID-19 clinical trials "
    "that might be relevant to his situation."
)

# Run the full multi-agent pipeline
result_state = run_pipeline(user_text)

# Print the final report generated by the agents
print(result_state["final_report"])
# Out:
# 2025-11-23 04:42:51,605 - INFO - Running IntakeAgent
# 2025-11-23 04:42:53,416 - INFO - intake took 1.81s
# 2025-11-23 04:42:53,417 - INFO - Running RetrievalAgent
# 2025-11-23 04:42:53,424 - INFO - retrieval took 0.01s
# 2025-11-23 04:42:53,424 - INFO - Running ExplainerAgent
# 2025-11-23 04:43:02,855 - INFO - explainer took 9.43s
# 2025-11-23 04:43:02,856 - INFO - Running ReportAgent
# 2025-11-23 04:43:02,857 - INFO - report took 0.00s
# # 🧭 Clinical Trials Navigator — Final Report
#
# ## Patient Profile
# ```json
# {
#   "age": 62,
#   "sex": "male",
#   "condition": "post-COVID-19 breathing problems",
#   "symptoms": "breathing problems",
#   "comorbidities": "diabetes",
#   "location": "Brazil"
# }
# ```
#
# ## Trials Found
# ```json
# {
#   "condition": "COVID",
#   "total_trials": 191,
#   "examples": [
#     {
#       "NCT Number": "NCT04376944",
#       "Title": "Barrier Measures to Limit Covid-19.Nosocomial Transmission: a Cross-sectional Evaluation",
#       "Phases": null,
#       "Status": "Recruiting"
#     },
#     {
#       "NCT Number": "NCT04476680",
#       "Title": "Influence of Military Preventive Policy for reCruit Training on COVID-19 Seroconversion",
#       "Phases": "Not Applicable",
#       "Status": "Recruiting"
#     },
#     {
#       "NCT Number": "NCT04452682",
#       "Title": "The Impact of COVID-19 Pandemic on Critical Limb Threatening Ischemia and Emergency Vascular Practice",
#       "Phases": null,
#       "Status": "Completed"
#     }
#   ]
# }
# ```
#
# ## Explanation
# Okay, let's break this down into easy-to-understand language.
#
# ---
#
# **Understanding Clinical Trials for COVID-19**
#
# This information tells us about some of the many studies happening right now related to **COVID-19**.
#
# *   **A Lot of Research:** There are a huge number of studies going on – **191 trials** in total – all trying to learn more about COVID-19.
#
# *   **What Kind of Studies Are These?**
#     It's important to know that many of these particular studies **aren't testing new drugs or vaccines**. Instead, they're often about understanding *how* COVID-19 works, spreads, or affects people and healthcare systems.
#
# *   **Here are a few examples to give you an idea:**
#
#     1.  **Preventing Spread in Hospitals (NCT04376944):**
#         *   This study is looking at **how to best use protective measures** (like masks, gloves, and distancing) to **prevent COVID-19 from spreading within hospitals**.
#         *   **Status:** They are **currently looking for participants** to join this study.
#
#     2.  **Military Policy and COVID-19 (NCT04476680):**
#         *   This trial is examining **how the rules and guidelines** (preventive policies) put in place during **military recruit training might affect how many people get COVID-19**.
#         *   **Status:** This study is **also recruiting new participants**.
#
#     3.  **COVID-19's Impact on Leg Problems (NCT04452682):**
#         *   This study investigated **how the COVID-19 pandemic affected patients who have very serious problems with blood flow to their legs** (called critical limb threatening ischemia) and how emergency care for these conditions was delivered during the pandemic.
#         *   **Status:** This study has **already finished collecting data** and is no longer looking for participants.
#
# **In Simple Terms:**
#
# These examples show that scientists and doctors are studying many different aspects of COVID-19, from practical ways to stop its spread, to how policies affect infection rates, and even how the pandemic influenced care for other serious health issues. The goal is to gather information that can help us better understand, prevent, and manage COVID-19 and its broader health impacts.
#
# ## Medical Disclaimer
# This report is generated by an AI agent and is not medical advice.
# Always consult a licensed healthcare professional.

# %% [markdown]
# # 10.1. Agent Evaluation Harness (complete, standalone)

# %%
import time
import json
import traceback
from IPython.display import display, Markdown

def evaluate_agent(input_text):
    """
    Evaluation harness for the multi-agent pipeline.
    Runs the full pipeline, measures performance,
    validates outputs, and returns a structured report.
    """

    print("🔍 Starting Agent Evaluation...\n")

    # Main evaluation container
    eval_report = {
        "input_text": input_text,
        "steps": [],
        "errors": [],
        "start_time": time.time(),
    }

    # Run the full pipeline
    t0 = time.time()
    try:
        state_output = run_pipeline(input_text)
        t1 = time.time()

        eval_report["steps"].append({
            "agent": "Pipeline (All Agents Sequential)",
            "duration_sec": round(t1 - t0, 3),
            "state_keys": list(memory.store.keys()),
        })

    except Exception:
        t1 = time.time()
        error_msg = traceback.format_exc()

        eval_report["errors"].append(error_msg)
        eval_report["steps"].append({
            "agent": "Pipeline FAILED",
            "duration_sec": round(t1 - t0, 3),
        })

        print("❌ Pipeline Failed\n")
        print(error_msg)
        return eval_report

    # Extract final outputs
    patient = memory.get("patient_profile")
    trials = memory.get("tool_result")
    explanation = memory.get("explanation")

    # Validation rules
    validation = {
        "patient_parsed": isinstance(patient, str) and len(patient) > 5,
        "tool_used": isinstance(trials, dict),
        "has_examples": isinstance(trials.get("examples", []), list),
        "explanation_ok": isinstance(explanation, str) and len(explanation) > 20,
    }

    score = sum(validation.values()) / len(validation)

    eval_report["validation"] = validation
    eval_report["final_score"] = round(score, 2)
    eval_report["total_runtime_sec"] = round(time.time() - eval_report["start_time"], 2)

    # UI summary
    display(Markdown("## ✅ Agent Evaluation Summary"))
    display(Markdown(f"**Final Score:** `{round(score * 100)}%`"))
    display(Markdown(f"**Runtime:** `{eval_report['total_runtime_sec']} sec`"))

    display(Markdown("### ✔ Validation Results"))
    display(Markdown("```json\n" + json.dumps(validation, indent=2) + "\n```"))

    display(Markdown("### 🔍 Pipeline State Keys"))
    display(Markdown("```json\n" + json.dumps(list(memory.store.keys()), indent=2) + "\n```"))

    display(Markdown("### 🧪 Scenario Input"))
    display(Markdown(f"```text\n{input_text}\n```"))

    display(Markdown("### 📦 Raw Trial Tool Output"))
    display(Markdown("```json\n" + json.dumps(trials, indent=2) + "\n```"))

    return eval_report

# %%
evaluate_agent("""
Patient: 62-year-old male with long COVID and breathing problems.
Comorbidities: diabetes.
Location: Brazil.
""")
# Out:
# 2025-11-23 04:43:02,897 - INFO - Running IntakeAgent
# 🔍 Starting Agent Evaluation...
# 2025-11-23 04:43:04,772 - INFO - intake took 1.87s
# 2025-11-23 04:43:04,773 - INFO - Running RetrievalAgent
# 2025-11-23 04:43:04,778 - INFO - retrieval took 0.00s
# 2025-11-23 04:43:04,779 - INFO - Running ExplainerAgent
# 2025-11-23 04:43:16,388 - INFO - explainer took 11.61s
# 2025-11-23 04:43:16,390 - INFO - Running ReportAgent
# 2025-11-23 04:43:16,390 - INFO - report took 0.00s
# ## ✅ Agent Evaluation Summary
# **Final Score:** `100%`
# **Runtime:** `13.49 sec`
# ### ✔ Validation Results
# ```json
# {
#   "patient_parsed": true,
#   "tool_used": true,
#   "has_examples": true,
#   "explanation_ok": true
# }
# ```
# ### 🔍 Pipeline State Keys
# ```json
# [
#   "patient_profile",
#   "tool_result",
#   "explanation",
#   "final_report"
# ]
# ```
# ### 🧪 Scenario Input
# ```text
#
# Patient: 62-year-old male with long COVID and breathing problems.
# Comorbidities: diabetes.
# Location: Brazil.
#
# ```
# ### 📦 Raw Trial Tool Output
# ```json
# {
#   "condition": "COVID",
#   "total_trials": 191,
#   "examples": [
#     {
#       "NCT Number": "NCT04376944",
#       "Title": "Barrier Measures to Limit Covid-19.Nosocomial Transmission: a Cross-sectional Evaluation",
#       "Phases": null,
#       "Status": "Recruiting"
#     },
#     {
#       "NCT Number": "NCT04476680",
#       "Title": "Influence of Military Preventive Policy for reCruit Training on COVID-19 Seroconversion",
#       "Phases": "Not Applicable",
#       "Status": "Recruiting"
#     },
#     {
#       "NCT Number": "NCT04452682",
#       "Title": "The Impact of COVID-19 Pandemic on Critical Limb Threatening Ischemia and Emergency Vascular Practice",
#       "Phases": null,
#       "Status": "Completed"
#     }
#   ]
# }
# ```
# {'input_text': '\nPatient: 62-year-old male with long COVID and breathing problems.\nComorbidities: diabetes.\nLocation: Brazil.\n',
#  'steps': [{'agent': 'Pipeline (All Agents Sequential)',
#    'duration_sec': 13.494,
#    'state_keys': ['patient_profile',
#     'tool_result',
#     'explanation',
#     'final_report']}],
#  'errors': [],
#  'start_time': 1763872982.8977103,
#  'validation': {'patient_parsed': True,
#   'tool_used': True,
#   'has_examples': True,
#   'explanation_ok': True},
#  'final_score': 1.0,
#  'total_runtime_sec': 13.49}

# %% [markdown]
# # 11. View Result Agent LLM

# %%
# Filter condition keyword
condition = "COVID"

# Select rows containing the condition
subset = df_small[df_small["Conditions"].str.contains(condition, case=False, na=False)]

# Replace NaN with None for JSON compatibility
subset = subset.replace({np.nan: None})

# Display filtered DataFrame
subset
# Out:
#      Rank   NCT Number                                              Title  \
# 1    2068  NCT04376944  Barrier Measures to Limit Covid-19.Nosocomial ...
# 2    3335  NCT04476680  Influence of Military Preventive Policy for re...
# 4     157  NCT04452682  The Impact of COVID-19 Pandemic on Critical Li...
# 6    4507  NCT04748120  Operative vs Non-Operative Management of Acute...
# 9    2214  NCT04502056  Covid-19 Messaging to Underserved Communities ...
# ..    ...          ...                                                ...
# 293  2925  NCT04336332  Randomized Comparison of Combination Azithromy...
# 294   507  NCT04765475           Protecting Native Families From COVID-19
# 295  1298  NCT04521296  Efficacy and Safety of DWJ1248 in Patients Wit...
# 297  2125  NCT04528901  Study of seroPREvalence Vis-à-vis SARS-CoV2 an...
# 299  2388  NCT04397796  Study of the Safety of Therapeutic Tx With Imm...
#
#          Acronym                   Status         Study Results  \
# 1       EMBELLIE               Recruiting  No Results Available
# 2    IMPACTCOVID               Recruiting  No Results Available
# 4           None                Completed  No Results Available
# 6           None  Enrolling by invitation  No Results Available
# 9           None   Active, not recruiting  No Results Available
# ..           ...                      ...                   ...
# 293         None   Active, not recruiting  No Results Available
# 294         None               Recruiting  No Results Available
# 295         None       Not yet recruiting  No Results Available
# 297      PRESAGE               Recruiting  No Results Available
# 299         None               Recruiting  No Results Available
#
#                                             Conditions  \
# 1                                  Caregivers|COVID-19
# 2    SARS-CoV Infection|Vitamin D Deficiency|Covid1...
# 4                         COVID|Critical Limb Ischemia
# 6    Covid19|Appendicitis|Cholecystitis, Acute|Chol...
# 9                                              Covid19
# ..                                                 ...
# 293                                SARS-CoV-2|COVID-19
# 294                                           COVID-19
# 295                          Mild to Moderate COVID-19
# 297                                           Covid-19
# 299                                              COVID
#
#                                          Interventions  \
# 1                                        Other: Survey
# 2                        Dietary Supplement: Vitamin D
# 4                               Other: COVID 19 impact
# 6    Procedure: Operative management|Procedure: Non...
# 9    Behavioral: Acknowledgement Racial Injustice A...
# ..                                                 ...
# 293  Combination Product: Hydroxychloroquine Sulfat...
# 294  Behavioral: Motivational Interviewing|Behavior...
# 295                        Drug: DWJ1248|Drug: Placebo
# 297                                               None
# 299        Biological: BM-Allo.MSC|Biological: Placebo
#
#                                       Outcome Measures  \
# 1    Proportion of caregivers and agents with a pos...
# 2    Seroconversion|Interim analysis - seropositivi...
# 4    The ICU admission with associated Pneumonia|Im...
# 6    Rate of pulmonary complications|Rate of pulmon...
# 9    The number of participants with knowledge of C...
# ..                                                 ...
# 293  Changes in patients viral load|Second evaluati...
# 294  TESTING: Proportion tested for COVID-19|TESTIN...
# 295  Time to SARS-CoV-2 eradication|Rate of SARS-Co...
# 297  Determine and compare the seroprevalence for S...
# 299  Incidence of AEs|Mortality|Death|Number of ven...
#
#                                  Sponsor/Collaborators  ...  \
# 1                     University Hospital, Montpellier  ...
# 2    Royal Centre for Defence Medicine|Leeds Becket...  ...
# 4                                  Mansoura University  ...
# 6                                 The Cleveland Clinic  ...
# 9    National Bureau of Economic Research, Inc.|Mas...  ...
# ..                                                 ...  ...
# 293        Rutgers, The State University of New Jersey  ...
# 294    Johns Hopkins Bloomberg School of Public Health  ...
# 295                   Daewoong Pharmaceutical Co. LTD.  ...
# 297            University Hospital, Strasbourg, France  ...
# 299                                  ImmunityBio, Inc.  ...
#
#                     Other IDs         Start Date Primary Completion Date  \
# 1              RECHMPL20_0261      April 1, 2020        December 1, 2020
# 2                1070MODREC20  September 1, 2020          April 28, 2021
# 4    R.20.06.898 - 2020/06/16       May 25, 2020           June 21, 2020
# 6                      20-525  December 28, 2020           June 28, 2021
# 9                     2029880      July 31, 2020      September 21, 2020
# ..                        ...                ...                     ...
# 293      002011|Pro2020000712      April 1, 2020          April 30, 2021
# 294               IRB00014147      March 8, 2021           February 2022
# 295             DW_DWJ1248201        August 2020           December 2020
# 297                      7879  September 4, 2020           December 2022
# 299        QUILT-COVID-19-MSC     August 3, 2020               June 2021
#
#         Completion Date       First Posted Results First Posted  \
# 1     December 30, 2020        May 6, 2020                 None
# 2        April 28, 2021      July 20, 2020                 None
# 4         June 21, 2020      June 30, 2020                 None
# 6    September 28, 2021  February 10, 2021                 None
# 9        September 2021     August 6, 2020                 None
# ..                  ...                ...                  ...
# 293      April 30, 2021      April 7, 2020                 None
# 294      September 2022  February 21, 2021                 None
# 295       December 2020    August 20, 2020                 None
# 297       December 2022    August 27, 2020                 None
# 299           June 2021       May 21, 2020                 None
#
#     Last Update Posted                                          Locations  \
# 1          May 6, 2020                Uh Montpellier, Montpellier, France
# 2       March 23, 2021  Headingley and City campuses, Leeds Beckett Un...
# 4        June 30, 2020               Mansoura university, Mansoura, Egypt
# 6    February 10, 2021  Cleveland Clinic Foundation, Cleveland, Ohio, ...
# 9    November 17, 2020  JPAL North America, Cambridge, Massachusetts, ...
# ..                 ...                                                ...
# 293  February 12, 2021  Saint Barnabas Medical Center, Livingston, New...
# 294     March 24, 2021  Johns Hopkins Center for American Indian Healt...
# 295    August 20, 2020                                               None
# 297   January 27, 2021  Les Hôpitaux Universitaires de Strasbourg, Str...
# 299     March 16, 2021  St. Francis Medical Center, Lynwood, Californi...
#
#     Study Documents                                          URL
# 1              None  https://ClinicalTrials.gov/show/NCT04376944
# 2              None  https://ClinicalTrials.gov/show/NCT04476680
# 4              None  https://ClinicalTrials.gov/show/NCT04452682
# 6              None  https://ClinicalTrials.gov/show/NCT04748120
# 9              None  https://ClinicalTrials.gov/show/NCT04502056
# ..              ...                                          ...
# 293            None  https://ClinicalTrials.gov/show/NCT04336332
# 294            None  https://ClinicalTrials.gov/show/NCT04765475
# 295            None  https://ClinicalTrials.gov/show/NCT04521296
# 297            None  https://ClinicalTrials.gov/show/NCT04528901
# 299            None  https://ClinicalTrials.gov/show/NCT04397796
#
# [191 rows x 27 columns]

# %%
# Create output DataFrame
df_output = pd.DataFrame([{
    "patient_profile": memory.get("patient_profile"),
    "tool_result": memory.get("tool_result"),
    "explanation": memory.get("explanation"),
    "final_report": memory.get("final_report")
}])

# Save as Excel (optional)
df_output.to_excel("/kaggle/working/\covid_trials_agent_results.xlsx",index=False)

# Display DataFrame
df_output
# Out:
#                                      patient_profile  \
# 0  ```json\n{\n  "age": 62,\n  "sex": "male",\n  ...
#
#                                          tool_result  \
# 0  {'condition': 'COVID', 'total_trials': 191, 'e...
#
#                                          explanation  \
# 0  Here's a breakdown of this clinical trial info...
#
#                                         final_report
# 0  # 🧭 Clinical Trials Navigator — Final Report\n...

# %% [markdown]
# # 12. Tool

# %%
def plot_trial_status():
    import matplotlib.pyplot as plt
    plt.style.use("seaborn-v0_8-whitegrid")

    # 1. Count and sort status categories
    counts = df_small["Status"].value_counts().sort_values()
    total = counts.sum()
    pct = (counts / total * 100).round(1)

    # 2. Advanced color palette (colors by category)
    color_map = {
        "Recruiting": "#2ecc71",
        "Completed": "#3498db",
        "Not yet recruiting": "#9b59b6",
        "Active, not recruiting": "#f1c40f",
        "Enrolling by invitation": "#1abc9c",
        "Withdrawn": "#e67e22",
        "Terminated": "#e74c3c",
        "Suspended": "#d35400",
        "No longer available": "#7f8c8d"
    }

    colors = [color_map.get(status, "#4ea8de") for status in counts.index]

    # 3. Plot horizontal bar chart
    plt.figure(figsize=(12, 7), dpi=120)
    bars = plt.barh(counts.index, counts.values, color=colors)

    plt.title("COVID-19 Clinical Trials by Recruitment Status", fontsize=16, weight="bold")
    plt.xlabel("Number of Trials", fontsize=13)
    plt.ylabel("Recruitment Status", fontsize=13)

    # 4. Add labels with count + percentage
    for i, bar in enumerate(bars):
        width = bar.get_width()
        label = f"{int(width)}  ({pct.iloc[i]}%)"
        plt.text(width + 2,
                 bar.get_y() + bar.get_height() / 2,
                 label,
                 va='center',
                 fontsize=11)

    # Clean grid
    plt.grid(axis="x", linestyle="--", alpha=0.3)

    plt.tight_layout()
    plt.savefig("trial_status.png", dpi=120)
    plt.close()

    return "trial_status.png"

# %%
TOOLS["plot_trial_status"] = plot_trial_status

# %%
from IPython.display import Image
plot_trial_status()
Image("/kaggle/working/trial_status.png")

# %% [markdown]
# # 13. Agent Evaluation

# %%
import time
import json
import logging
from concurrent.futures import ThreadPoolExecutor

logging.basicConfig(level=logging.INFO)

# ============================================================
# Corrigir IntakeAgent para usar input_text
# ============================================================

def fix_intake_agent():
    # sobrescreve método run do IntakeAgent
    def run_fixed(self, state):
        logging.info("Running IntakeAgent")
        text = state["input_text"]   # <<< corrigido aqui

        prompt = f"""
Extract a structured patient profile from this text.
Return JSON only.

{text}
"""
        response = self.model.generate_content(prompt)
        profile = response.text.strip()

        # Salvar no estado
        state["patient_profile"] = json.loads(profile)
        return state

    IntakeAgent.run = run_fixed

fix_intake_agent()


# ============================================================
# 1. Métricas avançadas
# ============================================================

def measure_agent(agent_name, fn, state):
    start = time.time()
    new_state = fn(state)
    end = time.time()

    duration = round(end - start, 3)
    logging.info(f"{agent_name} took {duration}s")
    return new_state, duration


# ============================================================
# 2. Execução paralela (corrigida)
# ============================================================

def run_parallel_intake_retrieval(state):

    intake = IntakeAgent("intake", "Parse patient", llm)
    retr   = RetrievalAgent("retrieval", "Find trials", llm)

    logging.info("Running Parallel Agents: Intake + Retrieval")

    with ThreadPoolExecutor(max_workers=2) as executor:
        f1 = executor.submit(intake.run, state)
        f2 = executor.submit(retr.run, state)

        s1 = f1.result()
        s2 = f2.result()

    return {**state, **s1, **s2}


# ============================================================
# 3. Validação A2A
# ============================================================

def validate_state(state):
    return {
        "patient_parsed": isinstance(state.get("patient_profile"), dict),
        "tool_used": "tool_result" in state,
        "has_examples": bool(state.get("tool_result", {}).get("examples")),
        "explanation_ok": len(state.get("explanation", "")) > 10
    }

def compute_score(v):
    return sum(v.values()) / len(v)


# ============================================================
# 4. JSON Export
# ============================================================

def export_run(full_state, filename="agent_run_export.json"):
    with open(filename, "w") as f:
        json.dump(full_state, f, indent=2)


# ============================================================
# 5. Avaliação FINAL (Sem Markdown)
# ============================================================

LEADERBOARD = []

def evaluate_agent_advanced(user_text):

    state = {"input_text": user_text}
    steps = []

    print("\n=== Advanced Agent Evaluation Started ===\n")
    total_start = time.time()

    # Parallel step ----------------
    state, t = measure_agent(
        "Parallel(Intake + Retrieval)",
        run_parallel_intake_retrieval,
        state
    )
    steps.append(("Parallel Intake/Retrieval", t))

    # Explainer --------------------
    expl = ExplainerAgent("explainer", "Explain trials", llm)
    state, t = measure_agent("Explainer", expl.run, state)
    steps.append(("Explainer", t))

    # Report -----------------------
    rep = ReportAgent("report", "Generate report", llm)
    state, t = measure_agent("Report", rep.run, state)
    steps.append(("Report", t))

    total_runtime = round(time.time() - total_start, 3)

    # Validation
    validation = validate_state(state)
    score = compute_score(validation)

    # Save final structure
    full_state = {
        "input": user_text,
        "steps": steps,
        "state": state,
        "validation": validation,
        "score": score,
        "runtime_sec": total_runtime
    }

    # Leaderboard
    LEADERBOARD.append({
        "input": user_text[:50],
        "score": score,
        "runtime": total_runtime
    })

    # Export JSON
    export_run(full_state)

    # Output simples (sem markdown)
    print("\n=== Evaluation Complete ===")
    print("Score:", round(score*100, 1), "%")
    print("Runtime:", total_runtime, "sec")
    print("\nValidation:", validation)
    print("\nSteps:", steps)
    print("\nState keys:", list(state.keys()))

    return full_state

# %%
# FIX — JSON SAFE PARSER WITH FALLBACK

import re
import json
import logging

def safe_json(text):
    """
    Extracts valid JSON from an LLM response.
    If JSON cannot be parsed, returns a minimal safe dictionary.
    """
    if not text or not isinstance(text, str):
        return {"error": "empty response"}

    # 1) Attempt direct JSON load
    try:
        return json.loads(text)
    except:
        pass

    # 2) Try extracting JSON between braces { }
    match = re.search(r"\{.*\}", text, re.DOTALL)
    if match:
        try:
            return json.loads(match.group(0))
        except:
            pass

    # 3) Safe minimal fallback
    return {"raw_text": text.strip(), "parsed": False}


def fix_intake_agent():
    def run_fixed(self, state):
        logging.info("Running IntakeAgent")

        text = state["input_text"]

        prompt = f"""
Extract a structured patient profile from the following text.
Return JSON only.

{text}
"""
        response = self.model.generate_content(prompt)
        raw_profile = response.text.strip()

        # Safe JSON parsing
        profile_json = safe_json(raw_profile)

        state["patient_profile"] = profile_json
        return state

    IntakeAgent.run = run_fixed


fix_intake_agent()

# %%
# Test Example
test_input = """
Patient: 62-year-old male with long COVID and breathing problems.
Comorbidities: diabetes.
Location: Brazil.
"""

# Run the full multi-agent evaluation
result = evaluate_agent_advanced(test_input)

# Print final output report
print(result["state"]["final_report"])
# Out:
# 2025-11-23 04:43:16,980 - INFO - Running Parallel Agents: Intake + Retrieval
# 2025-11-23 04:43:16,981 - INFO - Running IntakeAgent
# 2025-11-23 04:43:16,984 - INFO - Running RetrievalAgent
# === Advanced Agent Evaluation Started ===
# 2025-11-23 04:43:18,887 - INFO - Parallel(Intake + Retrieval) took 1.908s
# 2025-11-23 04:43:18,888 - INFO - Running ExplainerAgent
# 2025-11-23 04:43:31,695 - INFO - Explainer took 12.807s
# 2025-11-23 04:43:31,696 - INFO - Running ReportAgent
# 2025-11-23 04:43:31,697 - INFO - Report took 0.001s
# === Evaluation Complete ===
# Score: 100.0 %
# Runtime: 14.718 sec
#
# Validation: {'patient_parsed': True, 'tool_used': True, 'has_examples': True, 'explanation_ok': True}
#
# Steps: [('Parallel Intake/Retrieval', 1.908), ('Explainer', 12.807), ('Report', 0.001)]
#
# State keys: ['input_text', 'tool_result', 'status_plot_path', 'patient_profile', 'explanation', 'final_report']
# # 🧭 Clinical Trials Navigator — Final Report
#
# ## Patient Profile
# ```json
# {
#   "age": 62,
#   "sex": "male",
#   "condition": "long COVID",
#   "symptoms": "breathing problems",
#   "comorbidities": "diabetes",
#   "location": "Brazil"
# }
# ```
#
# ## Trials Found
# ```json
# {
#   "condition": "COVID",
#   "total_trials": 191,
#   "examples": [
#     {
#       "NCT Number": "NCT04376944",
#       "Title": "Barrier Measures to Limit Covid-19.Nosocomial Transmission: a Cross-sectional Evaluation",
#       "Phases": null,
#       "Status": "Recruiting"
#     },
#     {
#       "NCT Number": "NCT04476680",
#       "Title": "Influence of Military Preventive Policy for reCruit Training on COVID-19 Seroconversion",
#       "Phases": "Not Applicable",
#       "Status": "Recruiting"
#     },
#     {
#       "NCT Number": "NCT04452682",
#       "Title": "The Impact of COVID-19 Pandemic on Critical Limb Threatening Ischemia and Emergency Vascular Practice",
#       "Phases": null,
#       "Status": "Completed"
#     }
#   ]
# }
# ```
#
# ## Explanation
# Okay, let's break down this clinical trial information in a way that's easy to understand.
#
# ---
#
# ### Understanding COVID-19 Research
#
# You're looking at information about ongoing research related to **COVID-19**. This data tells us a few key things:
#
# *   **Total Research Happening:** There are a lot – **191 different studies, experiments, and evaluations** – currently happening or recently finished regarding COVID-19. This means scientists and doctors are working hard on many different aspects of the disease, not just treatments.
#
# *   **What are Clinical Trials?** Think of clinical trials as organized investigations designed to answer specific questions about health and illness. They help us learn how to prevent, diagnose, and treat diseases, or understand how they affect people.
#
# ---
#
# ### Looking at Specific Examples:
#
# Here are some examples of these COVID-19 studies:
#
# 1.  **NCT Number:** Each study gets a unique ID number, like a barcode, so you can easily find and track it. For example, `NCT04376944` is the ID for the first study mentioned.
#
# 2.  **Title (What the Study is About):**
#
#     *   **`NCT04376944: Barrier Measures to Limit Covid-19.Nosocomial Transmission: a Cross-sectional Evaluation`**
#         *   **In Simple Terms:** This study is looking at how well different "barrier measures" (like masks, gloves, and keeping distance) prevent COVID-19 from spreading **within hospitals**. It's a "snapshot" study, meaning they're evaluating things at a specific point in time.
#         *   **Phases:** `None` – This means it's not a study testing a new drug or treatment that typically goes through phases. It's more of an observational study or evaluation.
#         *   **Status:** `Recruiting` – This study is **currently looking for participants or collecting data**.
#
#     *   **`NCT04476680: Influence of Military Preventive Policy for reCruit Training on COVID-19 Seroconversion`**
#         *   **In Simple Terms:** This study is investigating how effective the COVID-19 prevention policies in the military are, particularly for new recruits, and how these policies affect whether recruits get infected.
#         *   **Phases:** `Not Applicable` – Again, this isn't a drug trial, but rather a study evaluating the impact of policies.
#         *   **Status:** `Recruiting` – This study is **currently looking for participants or collecting data**.
#
#     *   **`NCT04452682: The Impact of COVID-19 Pandemic on Critical Limb Threatening Ischemia and Emergency Vascular Practice`**
#         *   **In Simple Terms:** This study has finished and was looking into how the COVID-19 pandemic affected people with serious leg circulation problems (called Critical Limb Threatening Ischemia) and how emergency blood vessel doctors (vascular practice) had to adapt their work during the pandemic.
#         *   **Phases:** `None` – This was likely an observational study or review, not a new treatment trial.
#         *   **Status:** `Completed` – This study has **finished collecting all its data**. Researchers are now analyzing the results, and eventually, the findings will be published.
#
# ---
#
# ### Key Terms Explained:
#
# *   **Phases (None/Not Applicable):** In many clinical trials, especially those testing new medications or treatments, studies go through "phases" (Phase 1, 2, 3, 4) to make sure they are safe and effective. However, for these specific examples, you see `None` or `Not Applicable`. This means these aren't trials testing a new drug or device in the traditional sense. Instead, they are often **observational studies, policy evaluations, or surveys** that don't fit into those traditional drug-testing phases. It doesn't mean they're incomplete or less important; just a different *type* of research.
#
# *   **Status:**
#     *   **`Recruiting`:** The study is actively looking for people to join, or is currently gathering information/data.
#     *   **`Completed`:** The study has finished gathering all its information. Researchers are now analyzing the data, and results will be shared later.
#
# ---
#
# **In essence, this information shows that a wide range of research is happening to understand COVID-19 better – not just new treatments, but also how it spreads, how policies affect it, and its impact on other health conditions. If a study is "Recruiting," it means they might be looking for volunteers, and if you're interested, you could look it up using the NCT number.**
#
# ## Trial Status Chart
# Plot saved at: `trial_status.png`
#
# ## Medical Disclaimer
# This report is generated by an AI agent and is not medical advice.
# Always consult a licensed healthcare professional.
